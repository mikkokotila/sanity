# %%
import sanity

# %%
sanity.effect_check()
# Out:
# interactive(children=(IntSlider(value=10000, description='budget', max=1000000, min=1000, step=1000), FloatSli…

# %%
sanity.market_simulator()
# Out:
#      max_bid  start_budget  remain_budget  target_fill  impressions  \
# 0   0.758042    262.197378       0.058057    68.652011     345811.0
# 1   2.174538    122.311944      -0.010508    66.714123      59672.0
# 2   3.077255    322.574429      -0.006394    65.603735     116032.0
# 3   5.398487    262.453656      -0.008307    47.574382      64127.0
# 4   8.166287    211.523264      -0.000940    58.817905      36674.0
# 5  13.344255    184.644007      -0.006438    48.149506      21969.0
# 6  15.206168    147.871852      -0.001423    43.496987      11075.0
# 7  18.937873    169.563159      -0.007723    63.736518      11149.0
# 8  19.306864    172.377465      -0.016207    36.252073       9103.0
# 9  19.958171    434.869972      -0.000433    43.260832      22524.0
#
#      quality       eCPM
# 0  87.587110   0.758210
# 1  87.606834   2.049738
# 2  87.601183   2.780047
# 3  87.631006   4.092717
# 4  87.605361   5.767663
# 5  87.607379   8.404752
# 6  87.669571  13.351860
# ...
